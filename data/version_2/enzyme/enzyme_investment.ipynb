#
#      202035    202036    202037    202038    202039    202040
# ...

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_basex4.shape[1]):
    ax.plot(enzyme_basex4.iloc[:,replicate],color='grey')
ax.plot(enzyme_basex4.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ## basex10

# %%
enzyme_basex10 = pd.read_csv('Enzyme_basex10.csv',index_col=0)
enzyme_basex10.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.002348  0.002264  0.002232  0.002274  0.002044  0.002351  0.002445
# 1  0.002334  0.002253  0.002223  0.002266  0.002035  0.002342  0.002436
# 2  0.002325  0.002246  0.002215  0.002258  0.002028  0.002334  0.002427
# 3  0.002318  0.002238  0.002209  0.002252  0.002022  0.002326  0.002420
# 4  0.002314  0.002233  0.002205  0.002249  0.002018  0.002321  0.002416
#
#       20208     20209    202010  ...    202031    202032    202033    202034  \
# 0  0.002007  0.002401  0.002260  ...  0.002130  0.002165  0.002248  0.002205
# 1  0.001998  0.002391  0.002252  ...  0.002120  0.002156  0.002237  0.002197
# 2  0.001991  0.002380  0.002244  ...  0.002112  0.002149  0.002227  0.002190
# 3  0.001986  0.002372  0.002239  ...  0.002105  0.002143  0.002219  0.002183
# 4  0.001982  0.002367  0.002235  ...  0.002098  0.002140  0.002214  0.002178
#
#      202035    202036    202037    202038    202039    202040
# ...

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_basex10.shape[1]):
    ax.plot(enzyme_basex10.iloc[:,replicate],color='grey')
ax.plot(enzyme_basex10.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ## basex10_dis

# %%
enzyme_basex10_dis = pd.read_csv('Enzyme_basex10_dis.csv',index_col=0)
enzyme_basex10_dis.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.002348  0.002264  0.002232  0.002274  0.002044  0.002351  0.002445
# 1  0.002334  0.002253  0.002223  0.002266  0.002035  0.002342  0.002436
# 2  0.002325  0.002246  0.002215  0.002258  0.002028  0.002334  0.002427
# 3  0.002318  0.002238  0.002209  0.002252  0.002022  0.002326  0.002420
# 4  0.002314  0.002233  0.002205  0.002249  0.002018  0.002321  0.002416
#
#       20208     20209    202010  ...    202031    202032    202033    202034  \
# 0  0.002007  0.002401  0.002260  ...  0.002130  0.002165  0.002248  0.002205
# 1  0.001998  0.002391  0.002252  ...  0.002120  0.002156  0.002237  0.002197
# 2  0.001991  0.002380  0.002244  ...  0.002112  0.002149  0.002227  0.002190
# 3  0.001986  0.002372  0.002239  ...  0.002105  0.002143  0.002219  0.002183
# 4  0.001982  0.002367  0.002235  ...  0.002098  0.002140  0.002214  0.002178
#
#      202035    202036    202037    202038    202039    202040
# ...

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_basex10_dis.shape[1]):
    ax.plot(enzyme_basex10_dis.iloc[:,replicate],color='grey')
ax.plot(enzyme_basex10_dis.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ### Re-assembled dataset of years 3, 6, & 9

# %%
index_3   = [i for i in range(365*2+1,365*3+1)]
index_6   = [i for i in range(365*5+1,365*6+1)]
index_9   = [i for i in range(365*8+1,365*9+1)]
index_369 = index_3 + index_6 + index_9

# %%
enzyme_base369    = enzyme_base.iloc[index_369,:].reset_index(drop=True)
enzyme_basex4369  = enzyme_basex4.iloc[index_369,:].reset_index(drop=True)
enzyme_basex10369 = enzyme_basex10.iloc[index_369,:].reset_index(drop=True)

enzyme_base_dis369    = enzyme_base_dis.iloc[index_369,:].reset_index(drop=True)
enzyme_basex10_dis369 = enzyme_basex10_dis.iloc[index_369,:].reset_index(drop=True)

# %% [markdown]
# ## define confidence interval function

# %%
def confi_interval(df):
    alpha = 0.05
    
    lower = df.apply(
        lambda df: df.mean() - (stats.t.ppf(1 - alpha/2, df.count()-1) * df.std(ddof=1)/np.sqrt(df.count())),axis=1
    )
    upper = df.apply(lambda df: df.mean() + (stats.t.ppf(1 - alpha/2, df.count()-1) * df.std(ddof=1)/np.sqrt(df.count())),axis=1)
    
    return lower,upper

# %%
bound369    = confi_interval(enzyme_base369.iloc[:,:])
boundx4369  = confi_interval(enzyme_basex4369.iloc[:,:])
boundx10369 = confi_interval(enzyme_basex10369.iloc[:,:])

bounddis369    = confi_interval(enzyme_base_dis369.iloc[:,:])
boundx10dis369 = confi_interval(enzyme_basex10_dis369.iloc[:,:])

# %%
fig,ax = plt.subplots(1,1,figsize=(10,3))
ax.axvline(x=365*1, color='grey',linestyle='--',lw=3)
ax.axvline(x=365*2, color='grey',linestyle='--',lw=3)
ax.set_xlim(-5,365*3+5)
#ax.set_ylim(0.8,1.0)

ax.tick_params(bottom=False,labelbottom=False)    
#ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

#ax.set_xlabel('Year',size=16)
ax.set_ylabel("Enzyme Investment",size=16,weight='normal', color='k')
plt.figtext(0.23,0.05,'Year-3',fontsize=14)
plt.figtext(0.50,0.05,'Year-6',fontsize=14)
plt.figtext(0.75,0.05,'Year-9',fontsize=14)

plt.figtext(0.23,0.9,'ambient',fontsize=14)
plt.figtext(0.50,0.9,'drought',fontsize=14)
plt.figtext(0.75,0.9,'ambient',fontsize=14)

ax.plot(enzyme_basex10369.mean(axis=1)[365*1:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex10369.index[365*1:365*2],y1=boundx10369[0][365*1:365*2],y2=boundx10369[1][365*1:365*2], facecolor='red',alpha=1.0)
ax.fill_between(x=enzyme_basex10369.index[365*2:365*3],y1=boundx10369[0][365*2:365*3],y2=boundx10369[1][365*2:365*3], facecolor='red',alpha=1.0)


ax.plot(enzyme_basex4369.mean(axis=1)[365*1:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex4369.index[365*1:365*2], y1=boundx4369[0][365*1:365*2], y2=boundx4369[1][365*1:365*2], facecolor='orange', alpha=0.6)
ax.fill_between(x=enzyme_basex4369.index[365*2:365*3], y1=boundx4369[0][365*2:365*3], y2=boundx4369[1][365*2:365*3], facecolor='orange', alpha=0.6)

#ax.fill_between(x=drought_basex2369.index[365*1:365*2], y1=boundx2369[0][365*1:365*2], y2=boundx2369[1][365*1:365*2], facecolor='orange', alpha=1.0)
#ax.fill_between(x=drought_basex2369.index[365*2:365*3], y1=boundx2369[0][365*2:365*3], y2=boundx2369[1][365*2:365*3], facecolor='orange', alpha=1.0)


ax.plot(enzyme_base369.mean(axis=1)[365*0:365*1],color='k',linestyle='--')
ax.fill_between(x=enzyme_base369.index[365*0:365*1], y1=bound369[0][365*0:365*1],y2=bound369[1][365*0:365*1],facecolor='blue', alpha=1.0) 
ax.plot(enzyme_base369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax.fill_between(x=enzyme_base369.index[365*1:365*2], y1=bound369[0][365*1:365*2],y2=bound369[1][365*1:365*2],facecolor='blue', alpha=0.4) 
ax.plot(enzyme_base369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_base369.index[365*2:365*3], y1=bound369[0][365*2:365*3],y2=bound369[1][365*2:365*3],facecolor='blue', alpha=0.4) 

#ax.plot(enzyme_base369.mean(axis=1),color='red')
#ax.fill_between(x=enzyme_base369.index[365*0:365*1], y1=bound369[0][365*0:365*1],y2=bound369[1][365*0:365*1],facecolor='blue', alpha=1.0) 
#ax.fill_between(x=enzyme_base369.index[365*1:365*2], y1=bound369[0][365*1:365*2],y2=bound369[1][365*1:365*2],facecolor='blue', alpha=1.0) 
#ax.fill_between(x=enzyme_base369.index[365*2:365*3], y1=bound369[0][365*2:365*3],y2=bound369[1][365*2:365*3],facecolor='blue', alpha=1.0) 

#ax.legend()

#plt.savefig('legacy_sub.pdf',bbox_inches='tight')

plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(10,3))

ax.axvline(x=365*2, color='grey',linestyle='--',lw=3)
ax.set_xlim(365*1-5,365*3+5)
#ax.set_ylim(0.8,1.0)

ax.tick_params(bottom=False,labelbottom=False)    
#ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

#ax.set_xlabel('Year',size=16)
ax.set_ylabel("Enzyme Investment",size=16,weight='normal', color='k')
plt.figtext(0.27,0.05,'Year-6',fontsize=14)
plt.figtext(0.65,0.05,'Year-9',fontsize=14)

plt.figtext(0.27,0.9,'drought',fontsize=14)
plt.figtext(0.65,0.9,'ambient',fontsize=14)

ax.plot(enzyme_basex10369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex10369.index[365*1:365*2],y1=boundx10369[0][365*1:365*2],y2=boundx10369[1][365*1:365*2], facecolor='red',alpha=1.0)
ax.plot(enzyme_basex10369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex10369.index[365*2:365*3],y1=boundx10369[0][365*2:365*3],y2=boundx10369[1][365*2:365*3], facecolor='red',alpha=1.0)

ax.plot(enzyme_basex4369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex4369.index[365*1:365*2], y1=boundx4369[0][365*1:365*2], y2=boundx4369[1][365*1:365*2], facecolor='orange', alpha=0.6)
ax.plot(enzyme_basex4369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_basex4369.index[365*2:365*3], y1=boundx4369[0][365*2:365*3], y2=boundx4369[1][365*2:365*3], facecolor='orange', alpha=0.6)

ax.plot(enzyme_base369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax.fill_between(x=enzyme_base369.index[365*1:365*2], y1=bound369[0][365*1:365*2],y2=bound369[1][365*1:365*2],facecolor='blue', alpha=0.4) 
ax.plot(enzyme_base369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax.fill_between(x=enzyme_base369.index[365*2:365*3], y1=bound369[0][365*2:365*3],y2=bound369[1][365*2:365*3],facecolor='blue', alpha=0.4) 

#ax.legend()

#plt.savefig('legacy_sub.pdf',bbox_inches='tight')

plt.show()

# %% [markdown]
# ## default + plus

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,3))

alpha = 0.6

ax1.axvline(x=365*2, color='grey',linestyle='--',lw=3)
ax1.set_xlim(365*1-5,365*3+5)
ax1.set_ylim(0.0015,0.0035)
ax1.tick_params(bottom=False,labelbottom=False,labelsize=14)    
ax1.set_yticklabels(('1.5','2.0','2.5','3.0','3.5'))

ax1.set_ylabel("Enzyme investment(x10$^-$$^3$)",size=14,weight='heavy', color='k')
ax1.text(365+100,  0.00355,'drought',fontsize=14)
ax1.text(365*2+100,0.00355,'ambient',fontsize=14)
ax1.text(365+100,  0.00130,'Year-6',fontsize=14)
ax1.text(365*2+100,0.00130,'Year-9',fontsize=14)

ax1.plot(enzyme_basex10369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax1.fill_between(x=enzyme_basex10369.index[365*1:365*2],y1=boundx10369[0][365*1:365*2],y2=boundx10369[1][365*1:365*2], facecolor='red',alpha=alpha)
ax1.plot(enzyme_basex10369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax1.fill_between(x=enzyme_basex10369.index[365*2:365*3],y1=boundx10369[0][365*2:365*3],y2=boundx10369[1][365*2:365*3], facecolor='red',alpha=alpha)

ax1.plot(enzyme_basex4369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax1.fill_between(x=enzyme_basex4369.index[365*1:365*2], y1=boundx4369[0][365*1:365*2], y2=boundx4369[1][365*1:365*2], facecolor='orange', alpha=alpha)
ax1.plot(enzyme_basex4369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax1.fill_between(x=enzyme_basex4369.index[365*2:365*3], y1=boundx4369[0][365*2:365*3], y2=boundx4369[1][365*2:365*3], facecolor='orange', alpha=alpha)

ax1.plot(enzyme_base369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax1.fill_between(x=enzyme_base369.index[365*1:365*2], y1=bound369[0][365*1:365*2],y2=bound369[1][365*1:365*2],facecolor='blue', alpha=alpha) 
ax1.plot(enzyme_base369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax1.fill_between(x=enzyme_base369.index[365*2:365*3], y1=bound369[0][365*2:365*3],y2=bound369[1][365*2:365*3],facecolor='blue', alpha=alpha) 


ax2.axvline(x=365*2, color='grey',linestyle='--',lw=3)
ax2.set_xlim(365*1-5,365*3+5)
ax2.set_ylim(0.0015,0.0035)
ax2.tick_params(bottom=False,labelbottom=False,labelsize=14)    
ax2.set_yticklabels(('1.5','2.0','2.5','3.0','3.5'))

ax2.set_ylabel("Enzyme investment(x10$^-$$^3$)",size=14,weight='normal', color='k')
ax2.text(365+100,  0.00355,'drought',fontsize=14)
ax2.text(365*2+100,0.00355,'ambient',fontsize=14)

ax2.text(365+100,  0.00130,'Year-6',fontsize=14)
ax2.text(365*2+100,0.00130,'Year-9',fontsize=14)

ax2.plot(enzyme_basex10_dis369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax2.fill_between(x=enzyme_basex10_dis369.index[365*1:365*2],y1=boundx10dis369[0][365*1:365*2],y2=boundx10dis369[1][365*1:365*2], facecolor='red',alpha=alpha)
ax2.plot(enzyme_basex10_dis369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax2.fill_between(x=enzyme_basex10_dis369.index[365*2:365*3],y1=boundx10dis369[0][365*2:365*3],y2=boundx10dis369[1][365*2:365*3], facecolor='red',alpha=alpha)

ax2.plot(enzyme_base_dis369.mean(axis=1)[365*1:365*2],color='k',linestyle='--')
ax2.fill_between(x=enzyme_base_dis369.index[365*1:365*2], y1=bounddis369[0][365*1:365*2],y2=bounddis369[1][365*1:365*2],facecolor='blue', alpha=alpha) 
ax2.plot(enzyme_base_dis369.mean(axis=1)[365*2:365*3],color='k',linestyle='--')
ax2.fill_between(x=enzyme_base_dis369.index[365*2:365*3], y1=bounddis369[0][365*2:365*3],y2=bounddis369[1][365*2:365*3],facecolor='blue', alpha=alpha) 

#legend
blue_patch= mpatches.Patch(color='royalblue',label='ambient')
orange_patch= mpatches.Patch(color='orange',label='moderate')
red_patch = mpatches.Patch(color='tomato', label='severe')
plt.legend(handles=[blue_patch,orange_patch,red_patch],fontsize=12,frameon=False)


plt.subplots_adjust(wspace=0.3)

#plt.savefig('../figures/enzyme_trait.pdf',bbox_inches='tight')

plt.show()
