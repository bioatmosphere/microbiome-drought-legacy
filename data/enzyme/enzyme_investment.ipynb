# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

print("pandas version:", pd.__version__)
print('numpy version:',  np.__version__)
print('matplotlib version:',  matplotlib.__version__)
# Out:
# pandas version: 0.25.3
# numpy version: 1.17.4
# matplotlib version: 3.1.3

# %% [markdown]
# ## base

# %%
enzyme_base = pd.read_csv('Enzyme_base.csv',index_col=0)
enzyme_base.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.001144  0.001188  0.001137  0.001154  0.001011  0.001191  0.001233
# 1  0.001139  0.001183  0.001133  0.001151  0.001006  0.001187  0.001229
# 2  0.001135  0.001180  0.001129  0.001147  0.001004  0.001183  0.001226
# 3  0.001132  0.001176  0.001126  0.001146  0.001003  0.001179  0.001223
# 4  0.001129  0.001173  0.001125  0.001145  0.001002  0.001177  0.001221
#
#       20208     20209    202010  ...    202031    202032    202033    202034  \
# 0  0.000967  0.001205  0.001109  ...  0.001077  0.001074  0.001126  0.001120
# 1  0.000964  0.001201  0.001107  ...  0.001073  0.001070  0.001121  0.001118
# 2  0.000961  0.001198  0.001104  ...  0.001069  0.001066  0.001117  0.001115
# 3  0.000959  0.001195  0.001102  ...  0.001066  0.001063  0.001115  0.001112
# 4  0.000958  0.001192  0.001101  ...  0.001062  0.001061  0.001112  0.001110
#
#      202035    202036    202037    202038    202039    202040
# 0  0.001152  0.000988  0.000970  0.001037  0.001036  0.001133
# 1  0.001148  0.000984  0.000967  0.001033  0.001033  0.001129
# 2  0.001145  0.000981  0.000965  0.001029  0.001029  0.001126
# 3  0.001143  0.000979  0.000964  0.001027  0.001027  0.001124
# 4  0.001143  0.000977  0.000963  0.001024  0.001024  0.001123
#
# [5 rows x 40 columns]

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_base.shape[1]):
    ax.plot(enzyme_base.iloc[:,replicate],color='grey')
ax.plot(enzyme_base.mean(axis=1),color='red')

plt.show()

# %%
enzyme_all_base = pd.read_csv('Enzyme_all_base.csv',index_col=0)
enzyme_all_base.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.002348  0.002264  0.002232  0.002274  0.002044  0.002351  0.002445
# 1  0.002336  0.002253  0.002222  0.002267  0.002033  0.002341  0.002435
# 2  0.002325  0.002247  0.002212  0.002260  0.002027  0.002330  0.002427
# 3  0.002316  0.002239  0.002207  0.002257  0.002021  0.002321  0.002420
# 4  0.002312  0.002233  0.002202  0.002254  0.002019  0.002315  0.002415
#
#       20208     20209    202010  ...    202031    202032    202033    202034  \
# 0  0.002007  0.002401  0.002260  ...  0.002130  0.002165  0.002248  0.002205
# 1  0.001999  0.002391  0.002252  ...  0.002120  0.002156  0.002237  0.002198
# 2  0.001991  0.002382  0.002243  ...  0.002111  0.002146  0.002227  0.002191
# 3  0.001986  0.002375  0.002238  ...  0.002104  0.002139  0.002220  0.002185
# 4  0.001983  0.002367  0.002234  ...  0.002096  0.002134  0.002213  0.002180
#
#      202035    202036    202037    202038    202039    202040
# 0  0.002262  0.002029  0.001967  0.002112  0.002097  0.002259
# 1  0.002251  0.002017  0.001960  0.002102  0.002088  0.002250
# 2  0.002243  0.002009  0.001954  0.002094  0.002079  0.002242
# 3  0.002237  0.002002  0.001950  0.002089  0.002072  0.002236
# 4  0.002235  0.001997  0.001946  0.002083  0.002065  0.002232
#
# [5 rows x 40 columns]

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_all_base.shape[1]):
    ax.plot(enzyme_all_base.iloc[:,replicate],color='grey')
ax.plot(enzyme_all_base.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ## basex4

# %%
enzyme_basex4 = pd.read_csv('Enzyme_basex4.csv',index_col=0)
enzyme_basex4.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.002348  0.002264  0.002232  0.002274  0.002044  0.002351  0.002445
# 1  0.002336  0.002253  0.002222  0.002267  0.002033  0.002341  0.002435
# 2  0.002325  0.002247  0.002212  0.002260  0.002027  0.002330  0.002427
# 3  0.002316  0.002239  0.002207  0.002257  0.002021  0.002321  0.002420
# 4  0.002312  0.002233  0.002202  0.002254  0.002019  0.002315  0.002415
#
#       20208    202011    202012  ...    202031    202032    202033    202034  \
# 0  0.002007  0.002127  0.002165  ...  0.002130  0.002165  0.002248  0.002205
# 1  0.001999  0.002119  0.002156  ...  0.002120  0.002156  0.002237  0.002198
# 2  0.001991  0.002112  0.002150  ...  0.002111  0.002146  0.002227  0.002191
# 3  0.001986  0.002107  0.002142  ...  0.002104  0.002139  0.002220  0.002185
# 4  0.001983  0.002104  0.002138  ...  0.002096  0.002134  0.002213  0.002180
#
#      202035    202036    202037    202038    202039    202040
# 0  0.002262  0.002029  0.001967  0.002112  0.002097  0.002259
# 1  0.002251  0.002017  0.001960  0.002102  0.002088  0.002250
# 2  0.002243  0.002009  0.001954  0.002094  0.002079  0.002242
# 3  0.002237  0.002002  0.001950  0.002089  0.002072  0.002236
# 4  0.002235  0.001997  0.001946  0.002083  0.002065  0.002232
#
# [5 rows x 38 columns]

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_basex4.shape[1]):
    ax.plot(enzyme_basex4.iloc[:,replicate],color='grey')
ax.plot(enzyme_basex4.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ## basex10

# %%
enzyme_basex10 = pd.read_csv('Enzyme_basex10.csv',index_col=0)
enzyme_basex10.head()
# Out:
#       20201     20202     20203     20204     20205     20206     20207  \
# 0  0.002348  0.002264  0.002232  0.002274  0.002044  0.002351  0.002445
# 1  0.002336  0.002253  0.002222  0.002267  0.002033  0.002341  0.002435
# 2  0.002325  0.002247  0.002212  0.002260  0.002027  0.002330  0.002427
# 3  0.002316  0.002239  0.002207  0.002257  0.002021  0.002321  0.002420
# 4  0.002312  0.002233  0.002202  0.002254  0.002019  0.002315  0.002415
#
#       20208     20209    202010  ...    202031    202032    202033    202034  \
# 0  0.002007  0.002401  0.002260  ...  0.002130  0.002165  0.002248  0.002205
# 1  0.001999  0.002391  0.002252  ...  0.002120  0.002156  0.002237  0.002198
# 2  0.001991  0.002382  0.002243  ...  0.002111  0.002146  0.002227  0.002191
# 3  0.001986  0.002375  0.002238  ...  0.002104  0.002139  0.002220  0.002185
# 4  0.001983  0.002367  0.002234  ...  0.002096  0.002134  0.002213  0.002180
#
#      202035    202036    202037    202038    202039    202040
# 0  0.002262  0.002029  0.001967  0.002112  0.002097  0.002259
# 1  0.002251  0.002017  0.001960  0.002102  0.002088  0.002250
# 2  0.002243  0.002009  0.001954  0.002094  0.002079  0.002242
# 3  0.002237  0.002002  0.001950  0.002089  0.002072  0.002236
# 4  0.002235  0.001997  0.001946  0.002083  0.002065  0.002232
#
# [5 rows x 40 columns]

# %%
fig,ax = plt.subplots(1,1,figsize=(18,3))

ax.tick_params(axis='both',labelsize=14,bottom=True,labelbottom=True)

ax.set_xlabel('Day',size=14)
ax.set_ylabel('Enzyme',size=14)
ax.axvline(x=365*3, color='k',linestyle='-',lw=3)
ax.axvline(x=365*6, color='k',linestyle='-',lw=3)

for replicate in range(enzyme_basex10.shape[1]):
    ax.plot(enzyme_basex10.iloc[:,replicate],color='grey')
ax.plot(enzyme_basex10.mean(axis=1),color='red')

plt.show()

# %% [markdown]
# ### Re-assembled dataset of years 3, 6, & 9

# %%
index_3   = [i for i in range(365*2+1,365*3+1)]
index_6   = [i for i in range(365*5+1,365*6+1)]
index_9   = [i for i in range(365*8+1,365*9+1)]
index_369 = index_3 + index_6 + index_9

# %%
enzyme_base369    = enzyme_base.iloc[index_369,:].reset_index(drop=True)
enzyme_all_base369    = enzyme_all_base.iloc[index_369,:].reset_index(drop=True)

#drought_basex2369  = drought_basex2.iloc[index_369,:].reset_index(drop=True)

enzyme_basex4369  = enzyme_basex4.iloc[index_369,:].reset_index(drop=True)

enzyme_basex10369 = enzyme_basex10.iloc[index_369,:].reset_index(drop=True)

# %% [markdown]
# ## define confidence interval function

# %%
def confi_interval(df):
    alpha = 0.10
    
    lower = df.apply(
        lambda df: df.mean() - (stats.t.ppf(1 - alpha/2, df.count()-1) * df.std(ddof=1)/np.sqrt(df.count())),axis=1
    )
    upper = df.apply(lambda df: df.mean() + (stats.t.ppf(1 - alpha/2, df.count()-1) * df.std(ddof=1)/np.sqrt(df.count())),axis=1)
    
    return lower,upper

# %%
bound369    = confi_interval(enzyme_base369.iloc[:,:])
bound_all369    = confi_interval(enzyme_all_base369.iloc[:,:])

#boundx2369  = confi_interval(drought_basex2369.iloc[:,:])

boundx4369  = confi_interval(enzyme_basex4369.iloc[:,:])

boundx10369 = confi_interval(enzyme_basex10369.iloc[:,:])

# %%
fig,ax = plt.subplots(1,1,figsize=(10,3))
ax.axvline(x=365*1, color='grey',linestyle='--',lw=3)
ax.axvline(x=365*2, color='grey',linestyle='--',lw=3)
ax.set_xlim(-5,365*3+5)
#ax.set_ylim(0.8,1.0)

ax.tick_params(bottom=False,labelbottom=False)    
#ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)

#ax.set_xlabel('Year',size=16)
ax.set_ylabel("Enzyme Investment",size=16,weight='normal', color='k')
plt.figtext(0.23,0.05,'Year-3',fontsize=14)
plt.figtext(0.50,0.05,'Year-6',fontsize=14)
plt.figtext(0.75,0.05,'Year-9',fontsize=14)

plt.figtext(0.23,0.9,'ambient',fontsize=14)
plt.figtext(0.50,0.9,'drought',fontsize=14)
plt.figtext(0.75,0.9,'ambient',fontsize=14)

ax.plot(enzyme_basex10369.mean(axis=1)[365*1:365*3],color='k')
ax.fill_between(x=enzyme_basex10369.index[365*1:365*2],y1=boundx10369[0][365*1:365*2],y2=boundx10369[1][365*1:365*2], facecolor='red',alpha=1.0)
ax.fill_between(x=enzyme_basex10369.index[365*2:365*3],y1=boundx10369[0][365*2:365*3],y2=boundx10369[1][365*2:365*3], facecolor='red',alpha=1.0)


ax.plot(enzyme_basex4369.mean(axis=1)[365*1:365*3],color='k')
ax.fill_between(x=enzyme_basex4369.index[365*1:365*2], y1=boundx4369[0][365*1:365*2], y2=boundx4369[1][365*1:365*2], facecolor='orange', alpha=0.6)
ax.fill_between(x=enzyme_basex4369.index[365*2:365*3], y1=boundx4369[0][365*2:365*3], y2=boundx4369[1][365*2:365*3], facecolor='orange', alpha=0.6)

#ax.fill_between(x=drought_basex2369.index[365*1:365*2], y1=boundx2369[0][365*1:365*2], y2=boundx2369[1][365*1:365*2], facecolor='orange', alpha=1.0)
#ax.fill_between(x=drought_basex2369.index[365*2:365*3], y1=boundx2369[0][365*2:365*3], y2=boundx2369[1][365*2:365*3], facecolor='orange', alpha=1.0)


ax.plot(enzyme_all_base369.mean(axis=1)[365*0:365*1],color='k')
ax.fill_between(x=enzyme_all_base369.index[365*0:365*1], y1=bound_all369[0][365*0:365*1],y2=bound_all369[1][365*0:365*1],facecolor='blue', alpha=1.0) 
ax.plot(enzyme_all_base369.mean(axis=1)[365*1:365*2],color='k')
ax.fill_between(x=enzyme_all_base369.index[365*1:365*2], y1=bound_all369[0][365*1:365*2],y2=bound_all369[1][365*1:365*2],facecolor='blue', alpha=0.4) 
ax.plot(enzyme_all_base369.mean(axis=1)[365*2:365*3],color='k')
ax.fill_between(x=enzyme_all_base369.index[365*2:365*3], y1=bound_all369[0][365*2:365*3],y2=bound_all369[1][365*2:365*3],facecolor='blue', alpha=0.4) 

#ax.plot(enzyme_base369.mean(axis=1),color='red')
#ax.fill_between(x=enzyme_base369.index[365*0:365*1], y1=bound369[0][365*0:365*1],y2=bound369[1][365*0:365*1],facecolor='blue', alpha=1.0) 
#ax.fill_between(x=enzyme_base369.index[365*1:365*2], y1=bound369[0][365*1:365*2],y2=bound369[1][365*1:365*2],facecolor='blue', alpha=1.0) 
#ax.fill_between(x=enzyme_base369.index[365*2:365*3], y1=bound369[0][365*2:365*3],y2=bound369[1][365*2:365*3],facecolor='blue', alpha=1.0) 

#ax.legend()

#plt.savefig('legacy_sub.pdf',bbox_inches='tight')

plt.show()
